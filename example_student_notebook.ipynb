# %% [markdown]
# # Example Notebook for Students
#
# This notebook demonstrates how you will see **incomplete code** that you should finish,
# while the notebook still runs correctly in the background.
#
# ---

# %% [markdown]
# ## Task: Plot a sine function
#
# Fill in the missing part of the code below:
#
# ```python
# # TODO: Complete this code
# import numpy as np
# import matplotlib.pyplot as plt
#
# x = np.linspace(0, 10, 100)
# y = ???   # <-- replace ??? with the correct function of x
#
# plt.plot(x, y)
# plt.show()
# ```

# %%
# %% capture
# import numpy as np
# import matplotlib.pyplot as plt
#
# x = np.linspace(0, 10, 100)
# y = np.sin(x)   # Correct solution
#
# plt.plot(x, y)
# plt.title("Sine Function")
# plt.show()

# %%
# %who
# Out:
# np	 plt	 x	 y
